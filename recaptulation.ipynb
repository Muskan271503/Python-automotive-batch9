# %%
# Prints the title of the program
print("====== Student Evaluation System ======")

# ---------- Input Section ----------

# Takes the student's name as input (string)
name = input("Enter student name: ")

# Takes the student's age as input and converts it to integer
age = int(input("Enter age: "))

# Takes the student's marks as input and converts it to float
marks = float(input("Enter marks (0-100): "))

# ---------- Conditional Statements ----------

# Checks whether the student is a minor or an adult
if age < 18:
    category = "Minor"     # Assigned if age is less than 18
else:
    category = "Adult"     # Assigned if age is 18 or above

# ---------- Nested if-elif-else for grading ----------

# Checks marks and assigns grade accordingly
if marks >= 90:
    grade = "A"            # Grade A for marks 90 and above
elif marks >= 75:
    grade = "B"            # Grade B for marks between 75 and 89
elif marks >= 50:
    grade = "C"            # Grade C for marks between 50 and 74
else:
    grade = "Fail"         # Fail for marks below 50

# ---------- Output Formatting ----------

# Prints a blank line and heading for student details
print("\n--- Student Details ---")

# Displays student's name
print("Name:", name)

# Displays student's age
print("Age:", age)

# Displays student category (Minor/Adult)
print("Category:", category)

# Displays student's marks
print("Marks:", marks)

# Displays student's grade
print("Grade:", grade)

# ---------- Loop Control (for loop) ----------

# Prints heading for subject evaluation
print("\nSubjects Check:")

# List of subjects
subjects = ["Maths", "Science", "English", "Computer"]

# Loop through each subject in the list
for subject in subjects:
    
    # Skips the iteration when subject is English
    if subject == "English":
        continue           # continue skips to next loop iteration
    
    # Prints the subject being evaluated
    print("Evaluating:", subject)

# ---------- Loop Control (while loop) ----------

# Initializes attempts counter
attempts = 0

# Loop runs until attempts are less than 3
while attempts < 3:
    
    # Takes user choice and converts it to lowercase
    choice = input("\nDo you want to re-check marks? (yes/no): ").lower()
    
    # If user chooses yes
    if choice == "yes":
        print("Marks re-checked successfully.")
        break              # break exits the loop immediately
    
    # If user chooses no
    elif choice == "no":
        print("No re-check requested.")
        pass               # pass does nothing (placeholder)
    
    # If input is neither yes nor no
    else:
        print("Invalid choice.")
    
    # Increments attempt count
    attempts += 1

# Prints final message when program ends
print("\nThank you for using the system!")
# Out:
# ====== Student Evaluation System ======
#
# --- Student Details ---
# Name: Muskan
# Age: 24
# Category: Adult
# Marks: 67.0
# Grade: C
#
# Subjects Check:
# Evaluating: Maths
# Evaluating: Science
# Evaluating: Computer
# Marks re-checked successfully.
#
# Thank you for using the system!

# %%
# Printing program title using print() function (Output statement)
print("===== Python Recap Program =====")

# ---------- VARIABLES & INPUT (I/O EXPRESSIONS) ----------

# Taking name as input (string by default)
name = input("Enter your name: ")

# Taking age input and converting it into integer (Type Casting)
age = int(input("Enter your age: "))

# Taking marks input and converting it into float
marks = float(input("Enter your marks: "))

# Boolean variable declaration
is_student = True

# ---------- CONDITIONAL STATEMENTS ----------

# Checking age using if-else condition
if age < 18:
    category = "Minor"
else:
    category = "Adult"

# Nested if-elif-else to assign grade based on marks
if marks >= 90:
    grade = "A"
elif marks >= 75:
    grade = "B"
elif marks >= 50:
    grade = "C"
else:
    grade = "Fail"

# ---------- OUTPUT FORMATTING ----------

# Printing student details using formatted output
print("\n--- Student Details ---")
print("Name:", name)
print("Age:", age)
print("Category:", category)
print("Marks:", marks)
print("Grade:", grade)
print("Is Student:", is_student)

# ---------- OPERATORS ----------

# Arithmetic operator
total = marks + 10

# Comparison operator
passed = marks >= 50

# Logical operator
eligible = passed and is_student

# Displaying operator results
print("\nTotal after bonus:", total)
print("Passed:", passed)
print("Eligible:", eligible)

# ---------- FOR LOOP & CONTINUE ----------

# List data type
subjects = ["Maths", "Science", "English", "Computer"]

print("\nSubject Evaluation:")

# Looping through list using for loop
for subject in subjects:
    
    # Skip English using continue
    if subject == "English":
        continue
    
    # Printing remaining subjects
    print("Evaluating:", subject)

# ---------- WHILE LOOP, BREAK & PASS ----------

attempts = 0  # Loop control variable

# While loop runs maximum 3 times
while attempts < 3:
    
    choice = input("\nDo you want to re-check marks? (yes/no): ").lower()
    
    if choice == "yes":
        print("Marks re-checked successfully.")
        break        # Exits loop immediately
    
    elif choice == "no":
        print("No re-check requested.")
        pass         # Does nothing
    
    else:
        print("Invalid input.")
    
    attempts += 1   # Increment counter

# ---------- END ----------

print("\nProgram Ended Successfully")
# Out:
# ===== Python Recap Program =====
#
# --- Student Details ---
# Name: muskan
# Age: 24
# Category: Adult
# Marks: 76.0
# Grade: B
# Is Student: True
#
# Total after bonus: 86.0
# Passed: True
# Eligible: True
#
# Subject Evaluation:
# Evaluating: Maths
# Evaluating: Science
# Evaluating: Computer
# Marks re-checked successfully.
#
# Program Ended Successfully

# %%
# Introduction to Scripting

# This Python script demonstrates scripting concepts,
# data types, operators, I/O, control statements, and loops.

# =========================================================
# Python Variables, Datatypes, Keywords, Comments
# =========================================================

# Taking user input (I/O Expressions)
name = input("Enter your name: ")
age = int(input("Enter your age: "))
salary = float(input("Enter your salary: "))
is_employee = input("Are you an employee? (yes/no): ").lower() == "yes"

# Displaying basic datatypes
print("\n--- Basic Datatypes ---")
print("Name:", name, "| Type:", type(name))
print("Age:", age, "| Type:", type(age))
print("Salary:", salary, "| Type:", type(salary))
print("Is Employee:", is_employee, "| Type:", type(is_employee))

# =========================================================
# Type Conversion (Casting)
# =========================================================
print("\n--- Type Conversion ---")
age_float = float(age)
salary_int = int(salary)
print("Age converted to float:", age_float)
print("Salary converted to int:", salary_int)

# =========================================================
# Python Operators
# =========================================================
print("\n--- Operators ---")
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

# Arithmetic operators
print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)

# Comparison operators
print("a > b:", a > b)
print("a == b:", a == b)

# Logical operators
print("a > 0 and b > 0:", a > 0 and b > 0)

# Bitwise operators
print("Bitwise AND:", a & b)

# =========================================================
# Python Control Statements (if, elif, else)
# =========================================================
print("\n--- Conditional Statements ---")
if age < 18:
    print("You are a minor.")
elif age >= 18 and age < 60:
    print("You are an adult.")
else:
    print("You are a senior citizen.")

# Nested if
if is_employee:
    if salary > 50000:
        print("High salary employee")
    else:
        print("Regular salary employee")

# =========================================================
# Python Loop Control Statements
# =========================================================

# For loop
print("\n--- For Loop ---")
n = int(input("Enter a number to print numbers from 1 to n: "))
for i in range(1, n + 1):
    print(i, end=" ")
print()

# While loop
print("\n--- While Loop ---")
count = 1
while count <= 5:
    print("Count:", count)
    count += 1

# =========================================================
# break, continue, pass
# =========================================================
print("\n--- break, continue, pass ---")
for i in range(1, 6):
    if i == 3:
        continue   # skips 3
    if i == 5:
        break      # stops loop
    print(i)

for _ in range(2):
    pass  # placeholder statement


# =========================================================
# 2D List (List of Lists)
# =========================================================
print("\n--- 2D List ---")
rows = int(input("Enter number of rows: "))
cols = int(input("Enter number of columns: "))

matrix = []
for i in range(rows):
    row = []
    for j in range(cols):
        value = int(input(f"Enter element [{i}][{j}]: "))
        row.append(value)
    matrix.append(row)

print("2D List (Matrix):")
for row in matrix:
    print(row)

# =========================================================
# Formatting Output
# =========================================================
print("\n--- Formatted Output ---")
print("Hello {}, you are {} years old and earn {:.2f}".format(name, age, salary))
print(f"Name: {name}, Age: {age}, Salary: {salary}")

# =========================================================
# End of Script
# =========================================================
print("\nScript executed successfully.")
# Out:
# --- Basic Datatypes ---
# Name: muskan | Type: <class 'str'>
# Age: 24 | Type: <class 'int'>
# Salary: 30000.0 | Type: <class 'float'>
# Is Employee: True | Type: <class 'bool'>
#
# --- Type Conversion ---
# Age converted to float: 24.0
# Salary converted to int: 30000
#
# --- Operators ---
# Addition: 7
# Subtraction: -1
# Multiplication: 12
# Division: 0.75
# a > b: False
# a == b: False
# a > 0 and b > 0: True
# Bitwise AND: 0
#
# --- Conditional Statements ---
# You are an adult.
# Regular salary employee
#
# --- For Loop ---
# 1 2 3 4 5 6
#
# --- While Loop ---
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5
#
# --- break, continue, pass ---
# 1
# 2
# 4
#
# --- 2D List ---
# 2D List (Matrix):
# [2, 3, 3]
# [1, 2, 3]
# [2, 3, 4]
# [4, 4, 5]
#
# --- Formatted Output ---
# Hello muskan, you are 24 years old and earn 30000.00
# Name: muskan, Age: 24, Salary: 30000.0
#
# Script executed successfully.

# %%
# Introduction to Scripting
# This script shows how Python scripting works step by step

# Printing the purpose of the script
# Python scripts are executed line by line (interpreted language)

# =========================================================
# Python Variables, Datatypes, Keywords, Comments
# =========================================================

# Taking name input from the user (string by default)
name = input("Enter your name: ")

# Taking age input and converting it into integer using type casting
age = int(input("Enter your age: "))

# Taking salary input and converting it into float
salary = float(input("Enter your salary: "))

# Taking yes/no input, converting it to lowercase and checking condition
# Result will be True or False (Boolean)
is_employee = input("Are you an employee? (yes/no): ").lower() == "yes"

# Printing a heading for datatype display
print("\n--- Basic Datatypes ---")

# Printing name and its datatype
print("Name:", name, "| Type:", type(name))

# Printing age and its datatype
print("Age:", age, "| Type:", type(age))

# Printing salary and its datatype
print("Salary:", salary, "| Type:", type(salary))

# Printing employee status and its datatype
print("Is Employee:", is_employee, "| Type:", type(is_employee))

# =========================================================
# Type Conversion (Casting)
# =========================================================

# Printing section heading
print("\n--- Type Conversion ---")

# Converting integer age into float
age_float = float(age)

# Converting float salary into integer
salary_int = int(salary)

# Displaying converted values
print("Age converted to float:", age_float)
print("Salary converted to int:", salary_int)

# =========================================================
# Python Operators
# =========================================================

# Printing operators section heading
print("\n--- Operators ---")

# Taking first number input
a = int(input("Enter first number: "))

# Taking second number input
b = int(input("Enter second number: "))

# Arithmetic operators
print("Addition:", a + b)        # Adds two numbers
print("Subtraction:", a - b)     # Subtracts b from a
print("Multiplication:", a * b)  # Multiplies two numbers
print("Division:", a / b)        # Divides a by b

# Comparison operators
print("a > b:", a > b)           # Checks if a is greater than b
print("a == b:", a == b)         # Checks if a is equal to b

# Logical operator
print("a > 0 and b > 0:", a > 0 and b > 0)  # Logical AND

# Bitwise operator
print("Bitwise AND:", a & b)     # Bitwise AND operation

# =========================================================
# Python Control Statements (if, elif, else)
# =========================================================

# Printing conditional statements section heading
print("\n--- Conditional Statements ---")

# Checking age using if-elif-else
if age < 18:
    print("You are a minor.")     # Executed if condition is true
elif age >= 18 and age < 60:
    print("You are an adult.")    # Executed if above condition is false
else:
    print("You are a senior citizen.")  # Executed if all above are false

# Nested if condition
# Checking if user is an employee
if is_employee:
    
    # Checking salary inside employee condition
    if salary > 50000:
        print("High salary employee")
    else:
        print("Regular salary employee")

# =========================================================
# Python Loop Control Statements
# =========================================================

# For loop demonstration
print("\n--- For Loop ---")

# Taking number input
n = int(input("Enter a number to print numbers from 1 to n: "))

# Looping from 1 to n using range
for i in range(1, n + 1):
    print(i, end=" ")   # Printing values in same line

# Printing new line
print()

# While loop demonstration
print("\n--- While Loop ---")

# Initializing counter variable
count = 1

# While loop runs until condition becomes false
while count <= 5:
    print("Count:", count)  # Printing count value
    count += 1              # Incrementing counter

# =========================================================
# break, continue, pass
# =========================================================

# Printing loop control keywords section
print("\n--- break, continue, pass ---")

# For loop with break and continue
for i in range(1, 6):
    
    # Skips iteration when i equals 3
    if i == 3:
        continue
    
    # Stops loop completely when i equals 5
    if i == 5:
        break
    
    # Prints value of i
    print(i)

# Using pass as a placeholder
for _ in range(2):
    pass  # Does nothing

# =========================================================
# 2D List (List of Lists)
# =========================================================

# Printing 2D list section heading
print("\n--- 2D List ---")

# Taking number of rows
rows = int(input("Enter number of rows: "))

# Taking number of columns
cols = int(input("Enter number of columns: "))

# Creating empty matrix
matrix = []

# Outer loop for rows
for i in range(rows):
    row = []   # Creating empty row
    
    # Inner loop for columns
    for j in range(cols):
        value = int(input(f"Enter element [{i}][{j}]: "))
        row.append(value)  # Adding value to row
    
    matrix.append(row)     # Adding row to matrix

# Printing the 2D list
print("2D List (Matrix):")
for row in matrix:
    print(row)

# =========================================================
# Formatting Output
# =========================================================

# Printing formatted output section
print("\n--- Formatted Output ---")

# Using format() method
print("Hello {}, you are {} years old and earn {:.2f}".format(name, age, salary))

# Using f-string formatting
print(f"Name: {name}, Age: {age}, Salary: {salary}")

# =========================================================
# End of Script
# =========================================================

# Printing successful execution message
print("\nScript executed successfully.")
# Out:
# --- Basic Datatypes ---
# Name: Muskan Raj | Type: <class 'str'>
# Age: 24 | Type: <class 'int'>
# Salary: 40000.0 | Type: <class 'float'>
# Is Employee: True | Type: <class 'bool'>
#
# --- Type Conversion ---
# Age converted to float: 24.0
# Salary converted to int: 40000
#
# --- Operators ---
# Addition: 11
# Subtraction: -3
# Multiplication: 28
# Division: 0.5714285714285714
# a > b: False
# a == b: False
# a > 0 and b > 0: True
# Bitwise AND: 4
#
# --- Conditional Statements ---
# You are an adult.
# Regular salary employee
#
# --- For Loop ---
# 1 2 3 4 5 6 7
#
# --- While Loop ---
# Count: 1
# Count: 2
# Count: 3
# Count: 4
# Count: 5
#
# --- break, continue, pass ---
# 1
# 2
# 4
#
# --- 2D List ---
# 2D List (Matrix):
# [1, 7, 3]
# [5, 4, 3]
#
# --- Formatted Output ---
# Hello Muskan Raj, you are 24 years old and earn 40000.00
# Name: Muskan Raj, Age: 24, Salary: 40000.0
#
# Script executed successfully.
